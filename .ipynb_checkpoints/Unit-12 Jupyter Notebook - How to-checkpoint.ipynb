# %% [markdown]
# <div align="right"><font size=+1 color="red">สื่อดิจิทัลเพื่อการศึกษาอาชีวศึกษา</font><br>หลักสูตรประกาศนียบัตรวิชาชีพชั้นสูง ประเภทวิชาอุตสาหกรรม สาขาวิชาเทคนิคเครื่องกล </div>

# %% [markdown]
# # <center><font color="blue"> 30000-1304 วิทยาศาสตร์งานเครื่องกลและการผลิต<br>Science for Mechanical and Production Works (2-2-3)</center>
#
# <div align="right">บำรุง พ่วงเกิด PhD (Swansea, UK)<br>วิศวกรรมเครื่องกล สจล</div>

# %% [markdown]
# ![WinPython Logo](https://winpython.github.io/images/winpython_title.png)

# %% [markdown]
# # การติดตั้ง WinPython และ การใช้งาน Jupyter Notebooks

# %% [markdown]
# จูปิเตอร์โน๊ตบุกหรือสมุดจดจูปิเตอร์มีไฟล์นามสกุลคือ ".inpynb" เป็นที่รวมทั้งตัวอักษร สมการ รูปภาพ สื่อต่าง ๆ และโปรแกรมคอมพิวเตอร์พร้อมผลลัพท์ โดยที่โปรแกรมคอมพิวเตอร์หลักคือไพธอน ซึ่งเป็นภาษาคอมพิวเตอร์ที่ง่ายต่อการเรียนรู้ มีผู้นิยมใช้จำนวนมาก มีห้องสมุดของโค๊ดให้เลือกใช้ และใช้งานได้อย่างกว้างขวาง โน๊ตบุกทำงานบนเวปเพจ ทำให้สามารถสื่อสารได้อย่างมีประสิทธิภาพ พร้อมรองรับภาษาไทยได้เป็นอย่างดี
#
# นอกจากจูปิเตอร์โน๊ตบุกเป็นเครื่องมือที่นิยมใช้ที่สุดในวิทยาการข้อมูล ยังเหมาะสำหรับการสร้างเอกสารที่มีการตอบโต้ได้ ใช้สร้างเอกสารประกอบการเรียนรู้สมัยใหม่ได้เป็นอย่างดี แม้ว่าต้องใช้ความพยายามค่อนข้างสูงในขบวนการสร้างเอกสาร
#
# จูปิเตอร์โน๊ตบุกสามารถได้มาจากการติดตั้ง WinPython ซึ่งชุดการเขียนโปรแกรมแบบที่นำชุดโปรแกรมไปใช้ที่ไหนก็ได้ ไม่ต้องมีการติดตั้งใหม่

# %% [markdown]
# ![Jupyter Notebook Logo](https://www.auoychai.com/wp-content/uploads/2018/02/jupeter.png)

# %% [markdown]
# ## การติดตั้ง WinPython

# %% [markdown]
# เวปไซด์อย่างเป็นทางการของ WinPython คือ
#
# [https://winpython.github.io/](https://winpython.github.io/)
#
# โปรแกรมสำหรับการติดตั้งสามารถดาวน์โหลดได้จาก
#
# [https://sourceforge.net/projects/winpython/files/](https://sourceforge.net/projects/winpython/files/)
#
# ทั้งนี้ให้กดปุ่มสีเขียวเพื่อดาวน์โหลดเวอร์ชันล่าสุด
#
# [![กดปุ่มดาวน์โหลดเวอร์ชันล่าสุด](U12pics/download_latest.jpg)](https://sourceforge.net/projects/winpython/files/latest/download)
#
# ไฟล์สำหรับการติดตั้งดาวน์โหลดมาโดยอัตโนมัติ
#
# ![ดาวน์โหลด](U12pics/download.jpg)
#
# ให้คลิ๊กที่ไฟล์ที่ดาวน์โหลดมาเพื่อทำการติดตั้ง แนะนำให้ทำบนไดฟ์ D (หรือไดฟ์ C)
#
# ![ติดตั้ง](U12pics/install_extract.jpg)

# %% [markdown]
# เมื่อติดตั้งแล้วจะได้โฟลเดอร์ WPy64-xxxx อยู่บนไดฟ์ D เมื่อเปิดโฟลเดอร์ดูจะพบ
#
# ![โฟลเดอร์](U12pics/folder.jpg)
#
# เปิดโปรแกรม Jupyter Notebook.exe เพื่อได้แผงควบคุมเพื่อเปิดเอกสารจูปิเตอร์ โดยที่เอกสารจัดเก็บอยู่ในโฟลเดอร์ notebooks

# %% [markdown]
# # การแก้ปัญหา (Problem Solving)
#
# ทุกการประกอบอาชีพจำเป็นต้องแก้ปัญหา
#
# #### มห้ศจรรย์เลข 4 สำหรับความจำสั้น
#
# ในปี 2000 Nelson Cowan ตีพิมพ์ผลงานทางด้านจิตวิทยา ความจำสั้น (short-term memory:STM) จดจำได้ 4 อย่าง
#
# #### ขั้นตอนการแก้ปัญหาตามแบบโพลยา
#
# 1. เข้าใจปัญหา (Understand)
#     * สิ่งที่กำหนดมา (Given)
#     * ต้องการหาผลเฉลย (To Find)
# 1. วางแผนการแก้ปัญหา (Plan)
# 1. ดำเนินการแก้ปัญหาเพื่อหาคำตอบหรือผลเฉลย (Solve)
# 1. ตรวจสอบย้อนกลับ (Check)
#
# #### กฎสี่ประการสำหรับการเข้าใจปัญหา
#
# 1. ตารางของตัวเลข (Tables/Number Theory)
# 1. วาดรูปหรือเรขาคณิต (Graphs/Geometry)
# 1. สูตรสมการ (Formulas/Algebra)
# 1. คำบรรยายหรือพรรณา (Words)
#
# #### การได้มาซึ่งบทสรุปเพื่อการวางแผนแก้ปัญหา
#
# บทสรุป (Conclusion) ได้มาจากการให้เหตุผล (Reasoning) การให้เหตุผลมีสองรูปแบบ
#
# 1. การให้เหคุผลแบบอุปนัย (Inductive reasonings)
#     * เหตุผลที่ได้เรียกว่า การคาดคะเน (Conjecture) หรือการเดา (Guess)
# 1. การให้เหตุผลแบบนิรนัย (Deductive reasonings)
#     * กฎ (Law) เกิดจากการสังเกตุความเป็นไปในธรรมชาติหรือจากการทดลอง (Empiricism)
#     * ทฤษฎี (Theory) เิด้จากการประมวลความรู้ (Knowledge) ต้องมีการพิสูจน์
#     * กฎเกณฑ์ (Rule) เกิดจากการตั้งขึ้นมา
#
# #### แบบจำลองทางคณิตศาสตร์
#
# แบบจำลองทางคณิตศาสตร์ (Mathematical modeling) เป็นการเปลี่ยนจากปัญหาในธรรมชาติ
# ให้อยู่ในรูปของคณิตศาสตร์
#
# 1. กำหนดเป้าหมาย หรือสิ่งที่ไม่รู้ (Unknown) เป็นฟังก์ชันเป้าประสงค์ (Objective function)
# 1. ร่างรูป (Sketch) แสดงความสัมพันธ์ระหว่างฟังก์ชันเป้าประสงค์และตัวแปรอิสระต่าง ๆ
# 1. สร้างสูตรสมการ (Formulating equations) จากรูปที่ร่างไว้
#     * กำจัดตัวแปร จากความสัมพันธ์ที่คงที่
#     * กำหนดขอบเขตของปัญหา (Domain or Boundary of the problem)
# 1. ดำเนินการแก้ปัญหาเพื่อหาสิ่งที่ไม่รู้ ให้เป็นผลเฉลย (Solution)

# %% [markdown]
# ## ฟิสิกส์และกลศาสตร์
#
# ฟิสิกส์ (Physics) เป็นวิชาที่ศึกษาเกี่ยวความเป็นไปในธรรมชาติ ในแง่ของมวล (Mass) แรง (Force) และพลังงาน (Energy)
# โดยทำการวัดปริมาณที่วัดได้ (Measurable quantity) ปริมาณที่วัดได้วัดโดยการเทียบกับหน่วยการวัด (Unit) สิ่งที่ได้จากการวัดจำเป็นต้องบอกทั้ง ปริมาณ (Quantity) หน่วย (Unit) และความผิดพลาดในการวัด (Error)
#
#
# ความผิดพลาดในการวัดมักบอกโดยอ้อมจากเลขนัยสำคัญ (Significant figure) ตัวสุดท้ายเป็นค่าที่ไม่แน่นอน ในเชิงวิศวกรรมศาสตร์ เครื่องมือวัดที่ดีสุด วัดได้แม่นยำที่สุดได้ไม่เกิน 1% นั่นคือปริมาณที่ได้จากการวัดถูกรายงานด้วยเลขนัยสำคัญ
# ไม่เกิน 3 ตัว
#
# กลศาสตร์ เป็นสาขาย่อยของฟิสืกส์ศึกษา มวล แรง และการเคลื่อนที่ โดยมีปริมาณการวัดพื้นฐานอยู่ 4 อย่างคือ
#
# 1. ความยาว (Length)
# 1. เวลา (Time)
# 1. มวล (Mass)
# 1. แรง (Force)
#
# กลศาสตร์แบ่งตามการเปลี่ยนรูปของวัตถุเมื่อมีแรงมากระทำ
#
# 1. กลศาสตร์ของวัตถุแข็งเกร็ง (Rigid body mechanics) แบ่งเป็น
#     * สถิตศาสตร์ (Statics)
#     * พลศาสตร์ (Dynamics)
# 1. กลศาสตร์ของวัตถุที่เปลี่ยนรูปได้ (Deformable body mechanics)
#     * กลศาสตร์ของวัสดุ (Mechanics of Materials)
# 1. กลศาสตร์ของของไหล (Fluid mechanics) วัตถุเปลี่ยนรูปโดยไม่ต้องมีแรงภายนอกมากระทำ

# %% [markdown]
# ### งาน
#
# $$U_{1 \to 2} = \int_1^2 \vec F \cdot \, d\vec{r}$$
#
# ### หลักการของงานและพลังงาน
#
# $$U_{1 \to 2} + \dfrac{1}{2} m v_1^2 = \dfrac{1}{2} m v_2^2$$
#
# $$\boxed{U_{1 \to 2} + T_1 = T_2}$$

# %% [markdown]
# ## แรงพื้นฐาน
#
# * แรงโน้มถ่วง
# * แรงไฟฟ้าและแม่เหล็ก
# * แรงนิวเคลียร์
# * แรงอ่อน
